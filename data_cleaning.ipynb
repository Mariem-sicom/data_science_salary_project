# %% [markdown]
# ### Data cleaning:
# 1) Salary parsing: Removing '(Glassdoor est.)', 'K' and '$' / Adding new columns to indicate if the salary is given per hour or not, the min and max salaries and the averages
#
# 2) Adding a State field
#
# 3) Adding the Age of the company
#
# 4) Job Description parsing
#
# 5) Job Title parsing
#
# 6) Making hourly salary to annual

# %%
import pandas as pd

# %%
df1 = pd.read_csv("glassdoor_job_offers1.csv")
df2 = pd.read_csv("glassdoor_job_offers2.csv")
df3 = pd.read_csv("glassdoor_job_offers3.csv")
df4 = pd.read_csv("glassdoor_job_offers4.csv")

# %%
data = pd.concat([df1, df2, df3, df4])

# %%
data.shape
# Out:
# (330, 12)

# %%
# Remove duplicated observations
print(data.duplicated().sum())
data.drop_duplicates(inplace=True)

# Remove rows with salary value equal to -1
data = data[data["Salary Estimate"] != '-1'].reset_index(drop=True)
# Out:
# 90

# %%
# Salary parsing

# Remove '(Glassdoor est.)'
salary = data["Salary Estimate"].apply(lambda x: x.split('(')[0])

# Remove 'K' and '$'
salary = salary.apply(lambda x: x.replace('K', '').replace('$', ''))

# Some salaries are given per hour, so let's make a new column to indicate if the salary is per hour or not
data['Per_hour'] = data['Salary Estimate'].apply(lambda x: 1 if 'per hour' in x.lower() else 0)
salary = salary.apply(lambda x: x.replace('Per Hour', ''))

data['Salary'] = salary
data['Min_salary'] = salary.apply(lambda x: int(x.split('-')[0]))
data['Max_salary'] = salary.apply(lambda x: int(x.split('-')[1]))
data['Average_salary'] = (data['Min_salary'] + data['Max_salary'])/2

# %%
# State field
print( data['Location'])
data['Job_State'] = data['Location'].apply(lambda x: x.split(',')[1] if ',' in x else x)
# Out:
# 0       Alexandria, VA
# 1          Chicago, IL
# 2        Middleton, WI
# 3           Lorton, VA
# 4            Ogden, UT
#             ...
# 220             Remote
# 221         Draper, UT
# 222             Remote
# 223    Saint Louis, MO
# 224             Remote
# Name: Location, Length: 225, dtype: object

# %%
# Add the age of the company
data['Company_age'] = data['Founded'].apply(lambda x: (2021-x) if x>0 else x)

# %%
# Job Description parsing
data['Python_yn'] = data['Job Description'].apply(lambda x: 1 if 'python' in x.lower() else 0)
print(data['Python_yn'].value_counts())

data['AI_yn'] = data['Job Description'].apply(lambda x: 1 if 'ai' in x.lower() else 0)
print(data['AI_yn'].value_counts())

data['ML_yn'] = data['Job Description'].apply(lambda x: 1 if 'ml' in x.lower() else 0)
print(data['ML_yn'].value_counts())

data['Statistic_yn'] = data['Job Description'].apply(lambda x: 1 if 'statistic' in x.lower() else 0)
print(data['Statistic_yn'].value_counts())
# Out:
# 0    217
# 1      8
# Name: Python_yn, dtype: int64
# 1    122
# 0    103
# Name: AI_yn, dtype: int64
# 0    217
# 1      8
# Name: ML_yn, dtype: int64
# 0    182
# 1     43
# Name: Statistic_yn, dtype: int64

# %%
# Add Job Description length
data['desc_len'] = data['Job Description'].apply(lambda x: len(x))

# %%
data
# Out:
#                                              Job Title  \
# 0                                       Data Scientist
# 1                                   Sr. Data Scientist
# 2                                        R&D Scientist
# 3                                       Data Scientist
# 4                                        Data Engineer
# ..                                                 ...
# 220                           NLP - MRP Data Scientist
# 221                Data Scientist / Malware Researcher
# 222  Data Scientist - Senior Health Solutions - Remote
# 223                      Data Scientist - Intermediate
# 224                   Staff Data Scientist - AI Ethics
#
#                    Salary Estimate  \
# 0    $64K - $106K (Glassdoor est.)
# 1    $83K - $138K (Glassdoor est.)
# 2     $38K - $68K (Glassdoor est.)
# 3    $71K - $119K (Glassdoor est.)
# 4     $44K - $87K (Glassdoor est.)
# ..                             ...
# 220  $100K - $200K (Employer est.)
# 221  $100K - $200K (Employer est.)
# 222  $100K - $200K (Employer est.)
# 223  $100K - $200K (Employer est.)
# 224  $100K - $200K (Employer est.)
#
#                                        Job Description  Rating  \
# 0    Secure our Nation, Ignite your Future\nOvervie...     4.2
# 1    Sr. Data Scientist -INF0001YE\nDescription\n\n...     3.6
# 2    LGC, Biosearch Technologies is seeking a detai...     3.5
# 3    Who Are We?\nQinetiQ Inc. is a leading innovat...     2.5
# 4    Schedule: Mon- Fri Overview:\nThe data enginee...     3.8
# ..                                                 ...     ...
# 220  NLP-MRP Data Scientist\nLocation: Remote\nPurp...     4.3
# 221  Please Note:\n1. If you are a first time user,...     3.2
# 222  This position is on the data science team with...     4.3
# 223  KellyMitchell matches the best IT and business...     4.1
# 224  Your Job\nThe AI Ethics team at Indeed builds ...     4.4
#
#                           Company Name         Location  \
# 0    ManTech International Corporation   Alexandria, VA
# 1                        CNA Insurance      Chicago, IL
# 2                          LGC Limited    Middleton, WI
# 3                         QinetiQ Inc.       Lorton, VA
# 4           America First Credit Union        Ogden, UT
# ..                                 ...              ...
# 220                    Espire Services           Remote
# 221                           Broadcom       Draper, UT
# 222                    Mutual of Omaha           Remote
# 223                      KellyMitchell  Saint Louis, MO
# 224                             Indeed           Remote
#
#                         Size  Founded               Type of ownership  \
# 0    5001 to 10000 Employees     1968                Company - Public
# 1     1001 to 5000 Employees     1897                Company - Public
# 2     1001 to 5000 Employees     1842               Company - Private
# 3      501 to 1000 Employees     1956  Subsidiary or Business Segment
# 4     1001 to 5000 Employees     1939          Nonprofit Organization
# ..                       ...      ...                             ...
# 220        1 to 50 Employees       -1                        Contract
# 221         10000+ Employees     1991                Company - Public
# 222  5001 to 10000 Employees     1909               Company - Private
# 223   1001 to 5000 Employees     1998               Company - Private
# 224         10000+ Employees     2004               Company - Private
#
#                                   Industry  ...      Salary Min_salary  \
# 0                   Research & Development  ...   64 - 106          64
# 1                       Insurance Carriers  ...   83 - 138          83
# 2                Biotech & Pharmaceuticals  ...    38 - 68          38
# 3                      Aerospace & Defense  ...   71 - 119          71
# 4    Investment Banking & Asset Management  ...    44 - 87          44
# ..                                     ...  ...         ...        ...
# 220                                     -1  ...  100 - 200         100
# 221  Electrical & Electronic Manufacturing  ...  100 - 200         100
# 222                     Insurance Carriers  ...  100 - 200         100
# 223                 Staffing & Outsourcing  ...  100 - 200         100
# 224                               Internet  ...  100 - 200         100
#
#      Max_salary Average_salary  Job_State  Company_age  Python_yn AI_yn  \
# 0           106           85.0         VA           53          0     1
# 1           138          110.5         IL          124          0     0
# 2            68           53.0         WI          179          0     1
# 3           119           95.0         VA           65          0     1
# 4            87           65.5         UT           82          0     0
# ..          ...            ...        ...          ...        ...   ...
# 220         200          150.0     Remote           -1          0     0
# 221         200          150.0         UT           30          0     1
# 222         200          150.0     Remote          112          0     0
# 223         200          150.0         MO           23          1     0
# 224         200          150.0     Remote           17          0     1
#
#      ML_yn  Statistic_yn
# 0        0             0
# 1        0             0
# 2        0             0
# 3        1             0
# 4        0             0
# ..     ...           ...
# 220      0             0
# 221      0             0
# 222      0             0
# 223      0             1
# 224      0             0
#
# [225 rows x 23 columns]

# %%
# Job title and seniority
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'machine learning' in title.lower():
        return 'ml'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'not_specified'
    
    
def seniority(title):
    if 'senior' in title.lower() or 'sr' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'junior' in title.lower() or 'jr' in title.lower():
        return 'junior'
    else:
        return 'not_specified'

# %%
data['Simplified_title'] = data['Job Title'].apply(title_simplifier)

# %%
data['Seniority'] = data['Job Title'].apply(seniority)

# %%
# Make hourly salary to annual
# (2 = 2000/1000) and 2000 = 8h/day * 5d/week * 50w/year
data['Min_salary'] = data.apply(lambda x: x.Min_salary*2 if x.Per_hour==1 else x.Min_salary, axis=1)
data['Max_salary'] = data.apply(lambda x: x.Max_salary*2 if x.Per_hour==1 else x.Max_salary, axis=1)

# %%
data.to_csv("cleaned_data.csv", index=False)
